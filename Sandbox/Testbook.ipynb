# %%
echo "Hello World!"

# %%
import qiskit
ckt = qiskit.QuantumCircuit(2,3)
print(ckt)
ckt.h(0)

# Measure the qubits
ckt.measure([0, 1], [0, 1])

# Print Measurements
print(ckt)
# Out:
#
# q_0:
#
# q_1:
#
# c: 3/
#
#      ┌───┐┌─┐
# q_0: ┤ H ├┤M├
#      └┬─┬┘└╥┘
# q_1: ─┤M├──╫─
#       └╥┘  ║
# c: 3/══╩═══╩═
#        1   0
